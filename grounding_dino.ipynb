# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
# !git clone https://github.com/IDEA-Research/GroundingDINO.git
# %cd {HOME}/GroundingDINO

# we use latest Grounding DINO model API that is not official yet
# !git checkout feature/more_compact_inference_api

# !pip install -q -e .
# !pip install -q roboflow dataclasses-json onemetric
# Out:
# /kaggle/working
# Cloning into 'GroundingDINO'...
# remote: Enumerating objects: 437, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 437 (delta 153), reused 133 (delta 127), pack-reused 232
# Receiving objects: 100% (437/437), 12.86 MiB | 32.20 MiB/s, done.
# Resolving deltas: 100% (225/225), done.
# /kaggle/working/GroundingDINO
# Branch 'feature/more_compact_inference_api' set up to track remote branch 'feature/more_compact_inference_api' from 'origin'.
# Switched to a new branch 'feature/more_compact_inference_api'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# jupyterlab 4.1.6 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.2.1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
import torch
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)

import roboflow
import supervision

print(
    "roboflow:", roboflow.__version__, 
    "; supervision:", supervision.__version__
)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Mon_Apr__3_17:16:06_PDT_2023
# Cuda compilation tools, release 12.1, V12.1.105
# Build cuda_12.1.r12.1/compiler.32688072_0
# torch:  2.1 ; cuda:  2.1.2
# roboflow: 1.1.28 ; supervision: 0.4.0

# %%
import os

CONFIG_PATH = os.path.join(HOME, "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py")
print(CONFIG_PATH, "; exist:", os.path.isfile(CONFIG_PATH))
# Out:
# /kaggle/working/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py ; exist: True

# %%
# %cd {HOME}
# !mkdir {HOME}/weights
# %cd {HOME}/weights

# !wget -q https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# Out:
# /kaggle/working
# /kaggle/working/weights

# %%
import os

WEIGHTS_PATH = os.path.join(HOME, "weights", "groundingdino_swint_ogc.pth")
print(WEIGHTS_PATH, "; exist:", os.path.isfile(WEIGHTS_PATH))
# Out:
# /kaggle/working/weights/groundingdino_swint_ogc.pth ; exist: True

# %%
# %cd {HOME}/GroundingDINO

from groundingdino.util.inference import Model

model = Model(model_config_path=CONFIG_PATH, model_checkpoint_path=WEIGHTS_PATH)
# Out:
# /kaggle/working/GroundingDINO
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3526.)
# final text_encoder_type: bert-base-uncased
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
import cv2

import supervision as sv

# %%
import numpy as np
from dataclasses import dataclass
from typing import List, Tuple, Union, Optional
from dataclasses_json import dataclass_json
from supervision import Detections
import matplotlib.pyplot as plt


@dataclass_json
@dataclass
class COCOCategory:
    id: int
    name: str
    supercategory: str


@dataclass_json
@dataclass
class COCOImage:
    id: int
    width: int
    height: int
    file_name: str
    license: int
    date_captured: str
    coco_url: Optional[str] = None
    flickr_url: Optional[str] = None


@dataclass_json
@dataclass
class COCOAnnotation:
    id: int
    image_id: int
    category_id: int
    segmentation: List[List[float]]
    area: float
    bbox: Tuple[float, float, float, float]
    iscrowd: int


@dataclass_json
@dataclass
class COCOLicense:
    id: int
    name: str
    url: str


@dataclass_json
@dataclass
class COCOJson:
    images: List[COCOImage]
    annotations: List[COCOAnnotation]
    categories: List[COCOCategory]
    licenses: List[COCOLicense]


def load_coco_json(json_file: str) -> COCOJson:
    import json

    with open(json_file, "r") as f:
        json_data = json.load(f)

    return COCOJson.from_dict(json_data)


class COCOJsonUtility:
    @staticmethod
    def get_annotations_by_image_id(coco_data: COCOJson, image_id: int) -> List[COCOAnnotation]:
        return [annotation for annotation in coco_data.annotations if annotation.image_id == image_id]

    @staticmethod
    def get_annotations_by_image_path(coco_data: COCOJson, image_path: str) -> Optional[List[COCOAnnotation]]:
        image = COCOJsonUtility.get_image_by_path(coco_data, image_path)
        if image:
            return COCOJsonUtility.get_annotations_by_image_id(coco_data, image.id)
        else:
            return None

    @staticmethod
    def get_image_by_path(coco_data: COCOJson, image_path: str) -> Optional[COCOImage]:
        for image in coco_data.images:
            if image.file_name == image_path:
                return image
        return None

    @staticmethod
    def annotations2detections(annotations: List[COCOAnnotation]) -> Detections:
        class_id, xyxy = [], []

        for annotation in annotations:
            x_min, y_min, width, height = annotation.bbox
            class_id.append(annotation.category_id)
            xyxy.append([
                x_min,
                y_min,
                x_min + width,
                y_min + height
            ])

        return Detections(
            xyxy=np.array(xyxy, dtype=int),
            class_id=np.array(class_id, dtype=int)
        )

# %%
# %cd {HOME}

import roboflow
from roboflow import Roboflow

roboflow.login()

rf = Roboflow()
# Out:
# /kaggle/working
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here:  ····································

# %%
import os

DATA_SET_SUBDIRECTORY = "test"
ANNOTATIONS_FILE_NAME = "_annotations.coco.json"
IMAGES_DIRECTORY_PATH = os.path.join(dataset.location, DATA_SET_SUBDIRECTORY)
ANNOTATIONS_FILE_PATH = os.path.join(dataset.location, DATA_SET_SUBDIRECTORY, ANNOTATIONS_FILE_NAME)

# %%
coco_data = load_coco_json(json_file=ANNOTATIONS_FILE_PATH)

CLASSES = [
    category.name
    for category
    in coco_data.categories
    if category.supercategory != 'none'
]

IMAGES = [
    image.file_name
    for image
    in coco_data.images
]

# %%
import random
random.seed(10)

# %%
from onemetric.cv.object_detection import MeanAveragePrecision
from onemetric.cv.object_detection import ConfusionMatrix

# %%
import os


def list_image_files(directory: str) -> List[str]:
    image_extensions = [".jpeg", ".jpg", ".png", ".bmp", ".gif"]
    image_files = [f for f in os.listdir(directory) if os.path.splitext(f)[1].lower() in image_extensions]
    return image_files


def save_voc_xml(xml_string: str, file_path: str) -> None:
    with open(file_path, 'w') as f:
        f.write(xml_string)


def image_name_to_xml_name(image_name: str) -> str:
    base_name, _ = os.path.splitext(image_name)
    xml_name = f"{base_name}.xml"
    return xml_name

# %%
import os

PROJECT_NAME = "yellow"
PROJECT_DESCRIPTION = "yellow-smoke-dataset"
SOURCE_DIRECTORY_PATH = "/kaggle/working/output/"
CLASSES = ['yellow smoke']
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

# %%
from roboflow import Roboflow

workspace = Roboflow().workspace()
new_project = workspace.create_project(
    project_name=PROJECT_NAME,
    project_license="MIT",
    project_type="object-detection", 
    annotation=PROJECT_DESCRIPTION)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !mkdir output
from distutils.dir_util import copy_tree
from_dir = '/kaggle/input/output/OUTPUT'
to_dir = '/kaggle/working/output'
copy_tree(from_dir,to_dir)
# Out:
# ['/kaggle/working/output/img_428_jpg.rf.da327a4c05c8e752d5af35959b329b77.jpg',
#  '/kaggle/working/output/img_366_jpg.rf.b66d20c593726ad900b8ad909336313d.jpg',
#  '/kaggle/working/output/img_159_jpg.rf.88e2506fbdef67060a130854bc68e89e.jpg',
#  '/kaggle/working/output/img_293_jpg.rf.75280f04a610ee884f1b464bb6e58c50.jpg',
#  '/kaggle/working/output/img_129_jpg.rf.4d70a3bfe2230fce9003ae15ddc95d00.jpg',
#  '/kaggle/working/output/img_414_jpg.rf.1615a6ec62e78f2cfaf98c45961110c8.jpg',
#  '/kaggle/working/output/img_373_jpg.rf.78baca8106d2a9ef8e86094f6ac20c67.jpg',
#  '/kaggle/working/output/img_432_jpg.rf.29bbfbd77cda3ceaf1f3827efa7903fa.jpg',
#  '/kaggle/working/output/img_116_jpg.rf.d5c805022abc92214101ba870ca80cac.jpg',
#  '/kaggle/working/output/img_360_jpg.rf.ffba1c601c8fa675ccbb5025a9627f27.jpg',
#  '/kaggle/working/output/img_401_jpg.rf.7d1bc49648e590af0639c8e747b9ddde.jpg',
#  '/kaggle/working/output/img_202_jpg.rf.3aceae24981d63c6634d27b0ed74711f.jpg',
#  '/kaggle/working/output/img_255_jpg.rf.9f8c8587aef1bcd497b713e4c3c7e7f9.jpg',
#  '/kaggle/working/output/img_240_jpg.rf.b3e872907e979b77eb52ceb2ccbcd512.jpg',
#  '/kaggle/working/output/img_345_jpg.rf.83a9e380fa1fea49bcc13dfe59204fd7.jpg',
#  '/kaggle/working/output/img_307_jpg.rf.48144857cf9b878ae2d69176dd31fe79.jpg',
#  '/kaggle/working/output/img_121_jpg.rf.6c739a4d83555b5ada9654ed956da7f3.jpg',
#  '/kaggle/working/output/img_314_jpg.rf.13cf551e17c61e9e3de1ed9c10839a8f.jpg',
#  '/kaggle/working/output/img_391_jpg.rf.317debd33127858b1594b2dc16e30e84.jpg',
#  '/kaggle/working/output/img_224_jpg.rf.cc97d1dd9343a56aff67fdad9b6ff20e.jpg',
#  '/kaggle/working/output/img_172_jpg.rf.c4be4ce2ef6abe7e2e50199fcb90b5ec.jpg',
#  '/kaggle/working/output/img_128_jpg.rf.232d1463d058e24a2797f750055ced88.jpg',
#  '/kaggle/working/output/img_337_jpg.rf.a2f18e2e33257359119eb0a62d3c1cc8.jpg',
#  '/kaggle/working/output/img_385_jpg.rf.09a7d557415d9be2261431f7733117af.jpg',
#  '/kaggle/working/output/img_435_jpg.rf.93cb8781d06bab5713d0333e069e9e14.jpg',
#  '/kaggle/working/output/img_422_jpg.rf.942eaa0311d29be9d3fbb4ea4ce0d568.jpg',
#  '/kaggle/working/output/img_393_jpg.rf.c74b43fe8b1924c47dc9077ffc627bc1.jpg',
#  '/kaggle/working/output/img_317_jpg.rf.b9bf0e89ba48a28237cc237645f10dd3.jpg',
#  '/kaggle/working/output/img_126_jpg.rf.4c4112c40b1da35c2c3f12d1316997fe.jpg',
#  '/kaggle/working/output/img_140_jpg.rf.17c139b2f7ac5b6343dba5463767d2b6.jpg',
#  '/kaggle/working/output/img_276_jpg.rf.33aa41c09c068a36c2d097a5f5553b80.jpg',
#  '/kaggle/working/output/img_369_jpg.rf.54766db01272772240c53ac8234274e4.jpg',
#  '/kaggle/working/output/img_245_jpg.rf.875daf1711f751d7d186b9a3e758f3f7.jpg',
#  '/kaggle/working/output/img_423_jpg.rf.5044e8683259219d122db06ec4210328.jpg',
#  '/kaggle/working/output/img_305_jpg.rf.32fc56841a68a0004054313519ef3d6b.jpg',
#  '/kaggle/working/output/img_246_jpg.rf.0d82a8234908c1988abb9d2fa74b7b8f.jpg',
#  '/kaggle/working/output/img_374_jpg.rf.a829693527d2a7752341c9a7623e0428.jpg',
#  '/kaggle/working/output/img_351_jpg.rf.6fe17d428156737a679443344fa16b32.jpg',
#  '/kaggle/working/output/img_310_jpg.rf.c178dcf670597ec5c23c554c50cba5c3.jpg',
#  '/kaggle/working/output/img_138_jpg.rf.c4e65f9256c929c8d8a0d31ed79f39a8.jpg',
#  '/kaggle/working/output/img_362_jpg.rf.ce75ab142eca1d1a32ce67c4e522bf23.jpg',
#  '/kaggle/working/output/img_101_jpg.rf.7a3c657d17ad1e31638181f266393c76.jpg',
#  '/kaggle/working/output/img_413_jpg.rf.098956b1f83a1a9a578e777f8641ef86.jpg',
#  '/kaggle/working/output/img_78_jpg.rf.107d90d8856f6f84def0c50c011248c8.jpg',
#  '/kaggle/working/output/img_233_jpg.rf.24ca0b2f2200089550d0f8f6ad247d2e.jpg',
#  '/kaggle/working/output/img_117_jpg.rf.238bc65f4947ea3be302a8754811b1ae.jpg',
#  '/kaggle/working/output/img_342_jpg.rf.3b87bca1941b54abd44dd9f6d96f3748.jpg',
#  '/kaggle/working/output/img_155_jpg.rf.ab59f8e07514df393fdbddaea3edb41e.jpg',
#  '/kaggle/working/output/img_269_jpg.rf.48904002f395a19f15d2f51d344f89ca.jpg',
#  '/kaggle/working/output/img_316_jpg.rf.46b466b6995a9a137ed3d62a012785a7.jpg',
#  '/kaggle/working/output/img_13_jpg.rf.0ca73ccc0c788496aed0ff2a2a9423f9.jpg',
#  '/kaggle/working/output/img_137_jpg.rf.29e1959b11854ac24ddb0ea5bdbf4b1e.jpg',
#  '/kaggle/working/output/img_90_jpg.rf.451da1715e6a078015050efb95935f2d.jpg',
#  '/kaggle/working/output/img_379_jpg.rf.6efb89e3789c43dbcc42e16cc8880ee3.jpg',
#  '/kaggle/working/output/img_367_jpg.rf.faff1e291bd94a74723e609dbfa77aa3.jpg',
#  '/kaggle/working/output/img_193_jpg.rf.c2400e09b50862bf98bb9ac1fc32cc23.jpg',
#  '/kaggle/working/output/img_113_jpg.rf.48fde9fd172729b1fd983564d7a89708.jpg',
#  '/kaggle/working/output/img_416_jpg.rf.0c4bef4b89d4299ccf30af20ae2e0137.jpg',
#  '/kaggle/working/output/img_225_jpg.rf.932b59110045d7fc961d0f4cd9ab512a.jpg',
#  '/kaggle/working/output/img_222_jpg.rf.ea95cc9a2248b9b565e38a9078f41d8f.jpg',
#  '/kaggle/working/output/img_341_jpg.rf.daa2e1fce7638f4db61ba83de1cc689d.jpg',
#  '/kaggle/working/output/img_371_jpg.rf.cac4e86c7826e88515eb80ea2383e819.jpg',
#  '/kaggle/working/output/img_164_jpg.rf.dca57966f03f90c7399be165f4f01d27.jpg',
#  '/kaggle/working/output/img_354_jpg.rf.018a14cd75c7d69b267c5fb65b39fbf6.jpg',
#  '/kaggle/working/output/img_333_jpg.rf.6ad13d59d9748f42b524bd40cf65e236.jpg',
#  '/kaggle/working/output/img_87_jpg.rf.5df7d0e2b61342debea094a5db83b9b5.jpg',
#  '/kaggle/working/output/img_392_jpg.rf.c959901c452c5a2c4ef888b01daed4a3.jpg',
#  '/kaggle/working/output/img_395_jpg.rf.fa3cf4c25ef48e53b88443532ba1347f.jpg',
#  '/kaggle/working/output/img_402_jpg.rf.245d5decfc674c9789b8c056d2606164.jpg',
#  '/kaggle/working/output/img_311_jpg.rf.edf06f1ff3a71f351126bee66e3224b7.jpg',
#  '/kaggle/working/output/img_411_jpg.rf.ca098595403d1bd411abf7a805a36df4.jpg',
#  '/kaggle/working/output/img_409_jpg.rf.86cef06b3a32a33ead7b2ba74abc1218.jpg',
#  '/kaggle/working/output/img_312_jpg.rf.fa5f49c57d6d2b0f0c6cfddf001f8172.jpg',
#  '/kaggle/working/output/img_184_jpg.rf.5110b632cc161f59538d01a2d5113b22.jpg',
#  '/kaggle/working/output/img_250_jpg.rf.78435b88f01d842fe7220e20764df5ea.jpg',
#  '/kaggle/working/output/img_97_jpg.rf.9f70802370cc92e9967ec3c95fe54a55.jpg',
#  '/kaggle/working/output/img_150_jpg.rf.590cd8483576e13e6adf048cec8d08e2.jpg',
#  '/kaggle/working/output/img_427_jpg.rf.016706c12cb99dfe8fca697c083e47bb.jpg',
#  '/kaggle/working/output/img_223_jpg.rf.6a04105c4c3284ec71b6b26bad84b8eb.jpg',
#  '/kaggle/working/output/img_280_jpg.rf.50919aaa62e7eb3210be399379683c85.jpg',
#  '/kaggle/working/output/img_241_jpg.rf.cbafda256f9da10dd9a27b970ae61457.jpg',
#  '/kaggle/working/output/img_301_jpg.rf.deeed8f9de82b116ca29186c234373d8.jpg',
#  '/kaggle/working/output/img_186_jpg.rf.c83f5e6c1b5f35a22f0c5d36f124f3d7.jpg',
#  '/kaggle/working/output/img_328_jpg.rf.cabf43f3a31b22bd661630afdbd16ec0.jpg',
#  '/kaggle/working/output/img_238_jpg.rf.202a0599d65c3493300b364082c6ad96.jpg',
#  '/kaggle/working/output/img_148_jpg.rf.ea7b5b39e0e72739025efc8c8f64885a.jpg',
#  '/kaggle/working/output/img_154_jpg.rf.ef4c14bb0a6e55382d83e08772808c32.jpg',
#  '/kaggle/working/output/img_197_jpg.rf.ca2e95eca6d46c79b10829754e79715d.jpg',
#  '/kaggle/working/output/img_229_jpg.rf.1c5eb066674a2f1a6ba77d90ae1ee6b3.jpg',
#  '/kaggle/working/output/img_183_jpg.rf.65b314f1c0669324ac7f7a5a38182082.jpg',
#  '/kaggle/working/output/img_291_jpg.rf.a55e405cf96067228abf5e667d695092.jpg',
#  '/kaggle/working/output/img_168_jpg.rf.619582111851b48ba2442561cdbd3b86.jpg',
#  '/kaggle/working/output/img_144_jpg.rf.2d8db3b0a4e4d2eac3f472d25e11040c.jpg',
#  '/kaggle/working/output/img_383_jpg.rf.72b476cb666a99dffb2f2a6679a2399f.jpg',
#  '/kaggle/working/output/img_141_jpg.rf.f881a95026bfe5dbb3fe13f4c46b0da6.jpg',
#  '/kaggle/working/output/img_340_jpg.rf.23a1655693f511335393d4d3f88cfea2.jpg',
#  '/kaggle/working/output/img_303_jpg.rf.f56bd2079b364864cd3f255fe026f7c9.jpg',
#  '/kaggle/working/output/img_258_jpg.rf.22b0e38c6122ad15d574f91de6213a1f.jpg',
#  '/kaggle/working/output/img_210_jpg.rf.78f4658dcc6c18b83dc3a3da578e936f.jpg',
#  '/kaggle/working/output/img_133_jpg.rf.68ff8d1f280cd2b384a26b04b6dffe9e.jpg',
#  '/kaggle/working/output/img_387_jpg.rf.559ecb11688237127455a660af57aeea.jpg',
#  '/kaggle/working/output/img_331_jpg.rf.6c2dc5aeeb203a65de937f98413815cc.jpg',
#  '/kaggle/working/output/img_242_jpg.rf.4d852b26f4ffc03e031513ab7c3a0130.jpg',
#  '/kaggle/working/output/img_153_jpg.rf.7d5a20899c3685f707c209f6167c7925.jpg',
#  '/kaggle/working/output/img_171_jpg.rf.f7b944394ea10d63b33a1194a18429b0.jpg',
#  '/kaggle/working/output/img_194_jpg.rf.c587391c8834bb4a0209a48e086920d7.jpg',
#  '/kaggle/working/output/img_364_jpg.rf.8eb7e543c669c88082ed8d9acd0f30f2.jpg',
#  '/kaggle/working/output/img_32_jpg.rf.65b3d572083924e0554c5d9ad1ee426d.jpg',
#  '/kaggle/working/output/img_406_jpg.rf.90f4f0a36798672c7764e9ef1cd2fd75.jpg',
#  '/kaggle/working/output/img_290_jpg.rf.eb8200c392caf4b75b2b7cec9e6513c0.jpg',
#  '/kaggle/working/output/img_292_jpg.rf.37af07b026e21468de6cbc856ad609bf.jpg',
#  '/kaggle/working/output/img_410_jpg.rf.225b55aad37d011c74fd80d00186bec0.jpg',
#  '/kaggle/working/output/img_175_jpg.rf.b28fd2ccec241024442ad3b7256cf574.jpg',
#  '/kaggle/working/output/img_220_jpg.rf.52412ff7e3210b073d6d7c5ccad290f8.jpg',
#  '/kaggle/working/output/img_330_jpg.rf.64fe41daa60dc228ca0b70c0fd1c2fcf.jpg',
#  '/kaggle/working/output/img_236_jpg.rf.731a3521e234cea7c3e9062bf70ed7d4.jpg',
#  '/kaggle/working/output/img_165_jpg.rf.68bde3652cec15c72b5e2f3816652845.jpg',
#  '/kaggle/working/output/img_418_jpg.rf.24869f6b0cc0589e3a7876b48580981b.jpg',
#  '/kaggle/working/output/img_19_jpg.rf.b0c1f70a9917c5b43f5aeb7d9300656a.jpg',
#  '/kaggle/working/output/img_319_jpg.rf.36edf6ba7eda87ba0f71176be8d4823a.jpg',
#  '/kaggle/working/output/img_147_jpg.rf.99b5ac6d4e50dd34a1a6e4783b1e3441.jpg',
#  '/kaggle/working/output/img_91_jpg.rf.f3c7d7d708a2a4ab3c57997eddde2437.jpg',
#  '/kaggle/working/output/img_308_jpg.rf.81ec14be0c7e6007e6a16eb784885131.jpg',
#  '/kaggle/working/output/img_254_jpg.rf.75a61cb7a3fcdb96892739d6c4ffdf67.jpg',
#  '/kaggle/working/output/img_143_jpg.rf.88dd04fb4875309b52a63217737b542d.jpg',
#  '/kaggle/working/output/img_98_jpg.rf.72e12335a3b33389576b0ac83dfe5968.jpg',
#  '/kaggle/working/output/img_170_jpg.rf.707b1213bfe0f42d731ecbf096d6e96f.jpg',
#  '/kaggle/working/output/img_361_jpg.rf.b919de5f87c05762612077b7a08a22d2.jpg',
#  '/kaggle/working/output/img_339_jpg.rf.ae41630c834ee760dde339877ef9b22f.jpg',
#  '/kaggle/working/output/img_181_jpg.rf.08f3489e69709743bc28b86f564e0f6c.jpg',
#  '/kaggle/working/output/img_79_jpg.rf.0fa859f8fdd11072c84877382b2e9d64.jpg',
#  '/kaggle/working/output/img_278_jpg.rf.58b62f5612dabb42bc9f9847e9425617.jpg',
#  '/kaggle/working/output/img_221_jpg.rf.36019df3cceb4390c784e9075f126db8.jpg',
#  '/kaggle/working/output/img_257_jpg.rf.ce600baebfc2f15783bd13f2ab63c8bf.jpg',
#  '/kaggle/working/output/img_115_jpg.rf.540943489a17f00404ac5fc1696ae813.jpg',
#  '/kaggle/working/output/img_370_jpg.rf.2f8dadef30e39a616d054aa5f76387a4.jpg',
#  '/kaggle/working/output/img_349_jpg.rf.d80fdf4795e782b55d216a2f76aa6f69.jpg',
#  '/kaggle/working/output/img_102_jpg.rf.5717776e25c967aa73c922b232c52054.jpg',
#  '/kaggle/working/output/img_252_jpg.rf.759e428ac7cc8a83ee1817457e96935d.jpg',
#  '/kaggle/working/output/img_208_jpg.rf.58fc5b25a1a5fa90898ac212b978956b.jpg',
#  '/kaggle/working/output/img_346_jpg.rf.df93d8c925509e7924c51cdba035b88b.jpg',
#  '/kaggle/working/output/img_386_jpg.rf.aa53a037f725fe4de963b6a7a54cfb9e.jpg',
#  '/kaggle/working/output/img_363_jpg.rf.e2e0dd6dd14989af377c43d2ed8abd8c.jpg',
#  '/kaggle/working/output/img_109_jpg.rf.5ca138229fbf132adb558a088c1e62c6.jpg',
#  '/kaggle/working/output/img_163_jpg.rf.be21282ea6ef17ff786a6241f614424b.jpg',
#  '/kaggle/working/output/img_336_jpg.rf.d76872fb15abf387a952d6903129cec7.jpg',
#  '/kaggle/working/output/img_111_jpg.rf.26dc0a9a0a902220b60b5f40ecedf994.jpg',
#  '/kaggle/working/output/img_408_jpg.rf.68c938604683d3cf6a1f2b4d743e16b9.jpg',
#  '/kaggle/working/output/img_434_jpg.rf.44919cb9418c1d0f80efef017ed8ae2b.jpg',
#  '/kaggle/working/output/img_112_jpg.rf.90508e936f18ef312be1e28d79affc4b.jpg',
#  '/kaggle/working/output/img_196_jpg.rf.a0ee9848461f22a8ef7a9c55b6f0d866.jpg',
#  '/kaggle/working/output/img_400_jpg.rf.3fe718c7d5ba90ccc1195ae9f1fca349.jpg',
#  '/kaggle/working/output/img_174_jpg.rf.48f8a3b2c816efacb14153c4db9b927a.jpg',
#  '/kaggle/working/output/img_214_jpg.rf.86d22f25117354d0af8d06ba5f8bb8c6.jpg',
#  '/kaggle/working/output/img_122_jpg.rf.ebf4899ceeae85c3877a16c42f18cbbb.jpg',
#  '/kaggle/working/output/img_329_jpg.rf.fe18ebaba448686d37aa5182e9168b13.jpg',
#  '/kaggle/working/output/img_105_jpg.rf.84183951e5f8d247a6a8d05c7123bd93.jpg',
#  '/kaggle/working/output/img_134_jpg.rf.94cef43310c5538d5186272eeaa1a160.jpg',
#  '/kaggle/working/output/img_350_jpg.rf.43eb8ebd0301c45df2bc56d05d07b543.jpg',
#  '/kaggle/working/output/img_277_jpg.rf.ce1de86f7a52c2146724bc70479441b2.jpg',
#  '/kaggle/working/output/img_199_jpg.rf.7cd7d6e6c6d8ec7fa4e2a36ceb171857.jpg',
#  '/kaggle/working/output/img_353_jpg.rf.2cedfa69a5d9c2002c38205205acd6cc.jpg',
#  '/kaggle/working/output/img_283_jpg.rf.2d28f48f0ec8c62aa80aa634811506fe.jpg',
#  '/kaggle/working/output/img_377_jpg.rf.2aed7fc3fc2c7e564bc5024a256c6d15.jpg',
#  '/kaggle/working/output/img_232_jpg.rf.c59b16909f4b10181c70731ca225567f.jpg',
#  '/kaggle/working/output/img_173_jpg.rf.b8bb5a927b84db166aef996c676f06f0.jpg',
#  '/kaggle/working/output/img_136_jpg.rf.7e4aa18935493fc42fd9e3fc9eb3fa27.jpg',
#  '/kaggle/working/output/img_376_jpg.rf.259d7dbe14b30c08b1314a711823d9d7.jpg',
#  '/kaggle/working/output/img_326_jpg.rf.92cd83401fd909cb0e50b55288f855b6.jpg',
#  '/kaggle/working/output/img_166_jpg.rf.482136d8e0f18a2ebd2d5ef081f4e900.jpg',
#  '/kaggle/working/output/img_106_jpg.rf.9b905e5b6c48dc1281f42a2fd94db7b5.jpg',
#  '/kaggle/working/output/img_253_jpg.rf.ce7751d8a2b177e02cb744eb7a90e67a.jpg',
#  '/kaggle/working/output/img_352_jpg.rf.aa4c18bc9681d1493635128c829ec462.jpg',
#  '/kaggle/working/output/img_298_jpg.rf.73a3cce95f90790298d3e6983b5ada83.jpg',
#  '/kaggle/working/output/img_430_jpg.rf.0dfc1018947d732bf1d0383358bede14.jpg',
#  '/kaggle/working/output/img_119_jpg.rf.6219d2db2e211fbc1a6a1cb465970fd7.jpg',
#  '/kaggle/working/output/img_272_jpg.rf.4128e986764884494af1e0f5ec98dc46.jpg',
#  '/kaggle/working/output/img_118_jpg.rf.21a15c8d8ebbca811dd5168ad802e47b.jpg',
#  '/kaggle/working/output/img_404_jpg.rf.895c014cacf942adfbd4745d733933d5.jpg',
#  '/kaggle/working/output/img_107_jpg.rf.df53639c30158e77fdaae684718808d4.jpg',
#  '/kaggle/working/output/img_355_jpg.rf.4df126988b85f174a9e23e02e168fb42.jpg',
#  '/kaggle/working/output/img_169_jpg.rf.6f186159fd85ba48bd62879ae82b13bb.jpg',
#  '/kaggle/working/output/img_315_jpg.rf.d9e60d7eaa40ff5c6e111282ba310381.jpg',
#  '/kaggle/working/output/img_235_jpg.rf.22ccb87589bddc9c65bd8808e77445e7.jpg',
#  '/kaggle/working/output/img_158_jpg.rf.0bd9229c08c753bfc52756cadb917f69.jpg',
#  '/kaggle/working/output/img_403_jpg.rf.3a49c819f6c28eaf34559ea686bff323.jpg',
#  '/kaggle/working/output/img_282_jpg.rf.b67de5254cfcf74fe837a28fdeebed72.jpg',
#  '/kaggle/working/output/img_348_jpg.rf.334e980b5b7c6d31efb1033829a34781.jpg',
#  '/kaggle/working/output/img_249_jpg.rf.5d978abab76c8db5392e8cfef59f43e6.jpg',
#  '/kaggle/working/output/img_14_jpg.rf.d1544de819204e6bcfe59752d3a7cdcb.jpg',
#  '/kaggle/working/output/img_431_jpg.rf.b38466944a00a799d3109f23d8f596b2.jpg',
#  '/kaggle/working/output/img_135_jpg.rf.7d19f019d18ff431aa6987d7692e4a54.jpg',
#  '/kaggle/working/output/img_237_jpg.rf.9982463ad45a36c31c4a2935efad1f8a.jpg',
#  '/kaggle/working/output/img_338_jpg.rf.cf91161e86a9e4a41332ed34a50a37e0.jpg',
#  '/kaggle/working/output/img_421_jpg.rf.f7d082f3a90566f779893c1b241410da.jpg',
#  '/kaggle/working/output/img_198_jpg.rf.92391f63b96f6bb0f5ea2531609be040.jpg',
#  '/kaggle/working/output/img_396_jpg.rf.705cece0fc099aa56b2cc6c1f89f5d5b.jpg',
#  '/kaggle/working/output/img_318_jpg.rf.a6f553f637422759f48c8f67715c7100.jpg',
#  '/kaggle/working/output/img_124_jpg.rf.b6677d1188b2860a97b6617b5ce132d3.jpg',
#  '/kaggle/working/output/img_182_jpg.rf.61f5ee690c2e43e757106afb93da13dd.jpg',
#  '/kaggle/working/output/img_213_jpg.rf.f2d5e536423a1422969d0e84190d78d7.jpg',
#  '/kaggle/working/output/img_244_jpg.rf.b5616251914493b6449d72d3902ebccd.jpg',
#  '/kaggle/working/output/img_378_jpg.rf.9be01732a6f4b511eaaad940720bfcf2.jpg',
#  '/kaggle/working/output/img_381_jpg.rf.9f8454ad231a304b776ad2ab221b6898.jpg',
#  '/kaggle/working/output/img_357_jpg.rf.229c59db40ca5d7a0b042a0f3d0cf94d.jpg',
#  '/kaggle/working/output/img_304_jpg.rf.ee686ea8a30b158fc6c0bea72e3357f3.jpg',
#  '/kaggle/working/output/img_332_jpg.rf.6a02f2088610c7a984e974f8d45fb7d7.jpg',
#  '/kaggle/working/output/img_104_jpg.rf.87fb01b05621844a29aca8c4708e3642.jpg',
#  '/kaggle/working/output/img_388_jpg.rf.539b60c6d0dc64918fdba31f8e3e05fa.jpg',
#  '/kaggle/working/output/img_72_jpg.rf.8d2d35597421c0e248f9dcecd922d169.jpg',
#  '/kaggle/working/output/img_161_jpg.rf.361c631fe634161e1c8d3744470f0ce2.jpg',
#  '/kaggle/working/output/img_288_jpg.rf.9cd097fcd0cf5fede1533e5601a45ccc.jpg',
#  '/kaggle/working/output/img_382_jpg.rf.9207ee4bf0f389a3233153052fae146d.jpg',
#  '/kaggle/working/output/img_270_jpg.rf.fa76f7f5c4174706a0564208928c6727.jpg',
#  '/kaggle/working/output/img_259_jpg.rf.a9d9a52795c9cbe7eda7556b9b554f4d.jpg',
#  '/kaggle/working/output/img_322_jpg.rf.ae4eee417716f348b6bb6e8c9dd86ad5.jpg',
#  '/kaggle/working/output/img_142_jpg.rf.912bca37dad810197c4b2fe38b556c98.jpg',
#  '/kaggle/working/output/img_114_jpg.rf.ef6d3699cc032823b1d876a562f0bbf1.jpg',
#  '/kaggle/working/output/img_152_jpg.rf.8be6da71de4186cb8981ad166ad33f40.jpg',
#  '/kaggle/working/output/img_195_jpg.rf.f1ad5b72d1d982090879dea624bcccf2.jpg',
#  '/kaggle/working/output/img_88_jpg.rf.e884370005d08a53e8483c690e74d039.jpg',
#  '/kaggle/working/output/img_149_jpg.rf.42bc8215d33689508a84c137c7393756.jpg',
#  '/kaggle/working/output/img_397_jpg.rf.4d9c838fffef998f4e235e742e15fbc7.jpg',
#  '/kaggle/working/output/img_313_jpg.rf.3f5d4ce74be58b30f85d2ce700288040.jpg',
#  '/kaggle/working/output/img_15_jpg.rf.e0c0014957be30b5586cefeba3764c0b.jpg',
#  '/kaggle/working/output/img_16_jpg.rf.a6afa314aaf54ff9863896e48b8de160.jpg',
#  '/kaggle/working/output/img_2_jpg.rf.430e4f86fa2cdc9d94e544cd78836bc7.jpg',
#  '/kaggle/working/output/img_75_jpg.rf.f6b070798611ffa4c6b9ecec7ef4d997.jpg',
#  '/kaggle/working/output/img_151_jpg.rf.dd65f7b5e25d743d2139a5385aa1a376.jpg',
#  '/kaggle/working/output/img_179_jpg.rf.91c68abdd1427271e28aa249093316db.jpg',
#  '/kaggle/working/output/img_123_jpg.rf.62e17647c17c2bde7761d5cbd673dfa8.jpg',
#  '/kaggle/working/output/img_110_jpg.rf.c1b870bb1e224308dc3d08e49d92aaf1.jpg',
#  '/kaggle/working/output/img_358_jpg.rf.42f4a0b3dafa578506b938fa0b5c0f26.jpg',
#  '/kaggle/working/output/img_296_jpg.rf.71ee17fc6ca95ac770a7e00f705c3dc8.jpg',
#  '/kaggle/working/output/img_191_jpg.rf.ba09c3425812ed94cb62baf7671e509a.jpg',
#  '/kaggle/working/output/img_18_jpg.rf.e7f3feca10e20aa94986d4f5cb02e258.jpg',
#  '/kaggle/working/output/img_11_jpg.rf.5edbc79336541dbfe4d2b97b9df39c1a.jpg',
#  '/kaggle/working/output/img_81_jpg.rf.284c34849f16a738916631d6503918c8.jpg',
#  '/kaggle/working/output/img_248_jpg.rf.e10c8138b4fc30c44a1a284c030474f4.jpg',
#  '/kaggle/working/output/img_82_jpg.rf.fee0b1dec47bd6c8c3cea091914a3eb8.jpg',
#  '/kaggle/working/output/img_228_jpg.rf.41b0aa3e5c48bd751243d630edb79b73.jpg',
#  '/kaggle/working/output/img_287_jpg.rf.64ce6783b92c59b7cb128881e073534a.jpg',
#  '/kaggle/working/output/img_204_jpg.rf.ccccb1db8682c77854254f743c58cd3a.jpg',
#  '/kaggle/working/output/img_407_jpg.rf.1299965e2282789c5dcdfea1e32142c0.jpg',
#  '/kaggle/working/output/img_437_jpg.rf.76300e546c5b284e57d81b2032fd886b.jpg',
#  '/kaggle/working/output/img_294_jpg.rf.00a99bc2f9ba93eaa461596d3422cc58.jpg',
#  '/kaggle/working/output/img_176_jpg.rf.22b10f38568e56fee82ee4fa17e98798.jpg',
#  '/kaggle/working/output/img_132_jpg.rf.2442e52fb119b741e25b42054f8a1617.jpg',
#  '/kaggle/working/output/img_420_jpg.rf.2406e33c36f3efee79138b56934f079d.jpg',
#  '/kaggle/working/output/img_384_jpg.rf.aa83a78603ebabb0b3f620703dafe834.jpg',
#  '/kaggle/working/output/img_321_jpg.rf.c7cda6bc520934f22457d28b8660a2cc.jpg',
#  '/kaggle/working/output/img_429_jpg.rf.eb91973794322acc9867fb0b8dd8804d.jpg',
#  '/kaggle/working/output/img_157_jpg.rf.0a9017be8b71b026eff6a740c4bd675c.jpg',
#  '/kaggle/working/output/img_412_jpg.rf.299abc3ad431cbf8fa7e8d47b36c41ca.jpg',
#  '/kaggle/working/output/img_368_jpg.rf.a011bc906379b24460bed0d0d3480ea9.jpg',
#  '/kaggle/working/output/img_234_jpg.rf.c9c1c2460b669dd4a308650450a3c90b.jpg',
#  '/kaggle/working/output/img_375_jpg.rf.37995ed8e01fb3a83846783e4d7665e6.jpg',
#  '/kaggle/working/output/img_45_jpg.rf.1b4e7ef8662d70558e6397621169ce05.jpg',
#  '/kaggle/working/output/img_436_jpg.rf.23a90cbb802d100c83329b968a248597.jpg',
#  '/kaggle/working/output/img_356_jpg.rf.84a3afe010ff24ab6cad6eba573c7b79.jpg',
#  '/kaggle/working/output/img_160_jpg.rf.de4fa057f0e5503268e9ef17a632d9dd.jpg',
#  '/kaggle/working/output/img_286_jpg.rf.a12086f04118658fb70d70e224d9ca57.jpg',
#  '/kaggle/working/output/img_177_jpg.rf.1f9fd04441f3a9ef69159c85801b6201.jpg',
#  '/kaggle/working/output/img_320_jpg.rf.5243032bfef9a97c30dfd989a8910de8.jpg',
#  '/kaggle/working/output/img_433_jpg.rf.1081117990799c69f0359f007af9ab81.jpg',
#  '/kaggle/working/output/img_344_jpg.rf.1519e2d8e22ec18887d8fb784e6b92cb.jpg',
#  '/kaggle/working/output/img_419_jpg.rf.505870ee41af1474025a1084ae885fa7.jpg',
#  '/kaggle/working/output/img_415_jpg.rf.692bced0f24e5adaff2112da7e30f481.jpg',
#  '/kaggle/working/output/img_359_jpg.rf.c09cfd257fc13e2080ca85902bc2dacd.jpg',
#  '/kaggle/working/output/img_424_jpg.rf.c5537d23741d885b02b19a66df67e085.jpg',
#  '/kaggle/working/output/img_77_jpg.rf.4664e740cbf422b6992e038a1c8babbb.jpg',
#  '/kaggle/working/output/img_206_jpg.rf.b6f81374c3d1bc4cf35719fcd6cc48b9.jpg',
#  '/kaggle/working/output/img_145_jpg.rf.a3a5a1f00ed7a007e774aebf08261577.jpg',
#  '/kaggle/working/output/img_24_jpg.rf.5cc4085dc1ab5031ca59311c0cdb82a4.jpg',
#  '/kaggle/working/output/img_12_jpg.rf.6dd282ffd8f7768556c082ae72ff4c30.jpg',
#  '/kaggle/working/output/img_390_jpg.rf.13308259df7c9ff82036a5b6e8ddb976.jpg',
#  '/kaggle/working/output/img_281_jpg.rf.3cef47d2db68a53e96493f4e39d6cdd3.jpg',
#  '/kaggle/working/output/img_83_jpg.rf.eb78b367188cdcbc23b8ad8873e0f55c.jpg',
#  '/kaggle/working/output/img_405_jpg.rf.f25e8232f6bdf976406716004a0b6332.jpg',
#  '/kaggle/working/output/img_251_jpg.rf.8eb0f1b29536f131becfe2c13a5b8004.jpg',
#  '/kaggle/working/output/img_68_jpg.rf.41df2fbe13d68bd2162dba4226a3f04c.jpg',
#  '/kaggle/working/output/img_178_jpg.rf.b85a4699001224d2aaeac63c9992d16c.jpg',
#  '/kaggle/working/output/img_247_jpg.rf.5ff1cc4f88a32f37587ef66102c809e3.jpg',
#  '/kaggle/working/output/img_180_jpg.rf.e9e6c0bd3bbb38aa8d7899cf9c5c722d.jpg',
#  '/kaggle/working/output/img_217_jpg.rf.60da3e168557dd2f2ea9f666d0d84864.jpg',
#  '/kaggle/working/output/img_273_jpg.rf.df1f369b5d06a31ad0dda9effc3ea3d1.jpg',
#  '/kaggle/working/output/img_95_jpg.rf.07fa3f05eb8ff0bf756314fec3394f7e.jpg',
#  '/kaggle/working/output/img_426_jpg.rf.74164bd1aa0883fe5001969578927894.jpg',
#  '/kaggle/working/output/img_187_jpg.rf.475fd82344303475535124c4ed9d1534.jpg',
#  '/kaggle/working/output/img_394_jpg.rf.d421d5bea01574ec79d9daac7f56914a.jpg',
#  '/kaggle/working/output/img_71_jpg.rf.8cc53a3d55f5decde11a563da94436cc.jpg',
#  '/kaggle/working/output/img_256_jpg.rf.a1cf75e5e9cd9ae9d86c8ecd4c2667f3.jpg',
#  '/kaggle/working/output/img_306_jpg.rf.eec2c76d5deed69fddf95163bcc94f83.jpg',
#  '/kaggle/working/output/img_231_jpg.rf.080f2aa5ebe9986e9ca882756c2716ed.jpg',
#  '/kaggle/working/output/img_207_jpg.rf.fa41705952cefdc0383385902edd444c.jpg']

# %% [markdown]
# ### Detect and Upload Annotations to New Project
#
# Finally, how about putting Grounding DINO in front of a real test and using it to automatically annotate datasets. Labels will be sent to Roboflow where you can manually review them.

# %%
from os import listdir


for image_name in list_image_files(SOURCE_DIRECTORY_PATH):
    image_path = os.path.join(SOURCE_DIRECTORY_PATH, image_name)
    image = cv2.imread(image_path)
    height, width, depth = image.shape
    xml_name = image_name_to_xml_name(image_name=image_name)
    xml_path = os.path.join(SOURCE_DIRECTORY_PATH, xml_name)

    detections = model.predict_with_classes(
        image=image,
        classes=enhance_class_name(class_names=CLASSES),
        box_threshold=BOX_TRESHOLD,
        text_threshold=TEXT_TRESHOLD
    )

    detections = detections[detections.class_id != None]
    detections = detections[(detections.area / (height * width)) < 0.9 ]
    xml_string = sv.detections_to_voc_xml(
        detections=detections,
        classes=CLASSES,
        filename=image_name, 
        width=width, 
        height=height, 
        depth=depth
    )

    save_voc_xml(xml_string=xml_string, file_path=xml_path)
    new_project.upload(image_path=image_path, annotation_path=xml_path, split="train", overwrite=True)
